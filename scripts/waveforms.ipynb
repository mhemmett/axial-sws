# %%
# Import requirements
import pandas as pd
from get_all_traces import *
import matplotlib.pyplot as plt

# %%
# Load in catalog with date_time for pulling IRIS waveforms
test_catalog = pd.read_csv('../data/processed_catalog_date_time_10.csv')

# %%
# Iterate through get_trace for each event in catalog, using date_time as t_start and end_time as t_final
#for index, row in mini_catalog.iterrows():
#    t_start = row['date_time']
#    t_final = row['end_time']
#    get_trace(t_start, t_final)

# %%
get_all_traces(test_catalog, 'test_waveforms')
# Out:
# No data for AXCC1 HHE - No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# No data for AXCC1 HHN - No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# No data for AXCC1 HHZ - No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# No data for AXCC1 HDH - No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# No data for AXEC1 EHE - No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# No data for AXEC1 EHN - No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# No data for AXEC1 EHZ - No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# Retrieved data for AXEC2 HHE from 2014-11-04T20:46:01.600000Z to 2014-11-04T20:46:21.600000Z
# ...

# %%
#Now repeat trace for
